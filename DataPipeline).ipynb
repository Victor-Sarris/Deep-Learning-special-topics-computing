# %% [markdown]
# # INSTALACAO DE BIBLIOTECAS

# %% [markdown]
# Arquivo de pré-processamento

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# %% [markdown]
# # Definindo constantes

# %%
BATCH_SIZE = 32
IMG_SIZE = (224, 224) # Tamanho padrão para modelos como MobileNet/ResNet
EPOCHS = 10

# %% [markdown]
# # Carregando os dados de Treino

# %%
valid_dataset = image_dataset_from_directory(
    'valid',
    shuffle=True,
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    label_mode='binary'
)

# %% [markdown]
# # Carregando os dados de Teste (para avaliação final)

# %%
test_dataset = image_dataset_from_directory(
    'test',
    shuffle=False, # Não precisamos embaralhar o teste
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    label_mode='binary'
)

# %% [markdown]
# # Pré-processamento extra: Otimização de performance no carregamento

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_dataset = train_dataset.cache().prefetch(buffer_size=AUTOTUNE)
valid_dataset = valid_dataset.cache().prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.cache().prefetch(buffer_size=AUTOTUNE)
